# %%
pip install pymongo
# Out:
# Defaulting to user installation because normal site-packages is not writeable
# Collecting pymongo
#   Downloading pymongo-4.0.1-cp310-cp310-win_amd64.whl (354 kB)
# Installing collected packages: pymongo
# Successfully installed pymongo-4.0.1
# Note: you may need to restart the kernel to use updated packages.

# %%
import pymongo
from pymongo import MongoClient
from pymongo.errors import ConnectionFailure

client = MongoClient('localhost',27017)
#db.create_collection("clasemongodb")
db = client["clasemongodb"]

listas= db.listas

import numpy as np
import random

print("LISTADO DE CIUDADANOS")
nombres=["Luis","Miguel","Kevin","Dustin","Paula","Steven","Paul","Jorge","Ricardo","Eduardo"]
apellidos=["Muzo","Chavez","Pinanjota","Perez","Zambrano","Zaldumbide","Guaniuna","Espinoza","Escobar","Monteros"]


k=int(input("INGRESE N CIUDADANOS"))

for i in range(k):
    a = np.random.randint(low=1, high=1000000009, size=1).tolist()
    
    edad = np.random.randint(low=18, high=80, size=1).tolist()

    

    nom_C=[]
    ape_C=[]
    
    
    for i in range (2):
        n=np.random.randint(0,9)
        nom_C.append(nombres[n])

    print(nom_C)
    
    


    for i in range (2):
        n=np.random.randint(0,9)
        ape_C.append(apellidos[n])
        
    print(ape_C)
    print(edad)
    
    p=a[0]*9
    print(p)

    
    print("--------------------------------------------------------------------------------")
    
    
    script=[{'Nombres_Completos':nom_C,'Apellidos_Completos':ape_C,'Edad:':edad,'Cedula:':p}]
    
    listas.insert_many(script)
# Out:
# LISTADO DE CIUDADANOS
# INGRESE N CIUDADANOS5
# ['Dustin', 'Kevin']
# ['Escobar', 'Zaldumbide']
# [58]
# 6430061808
# --------------------------------------------------------------------------------
# ['Paul', 'Dustin']
# ['Pinanjota', 'Espinoza']
# [38]
# 2171309769
# --------------------------------------------------------------------------------
# ['Miguel', 'Luis']
# ['Chavez', 'Guaniuna']
# [65]
# 4796520336
# --------------------------------------------------------------------------------
# ['Steven', 'Jorge']
# ['Zaldumbide', 'Muzo']
# [38]
# 8341931448
# --------------------------------------------------------------------------------
# ['Paula', 'Luis']
# ['Guaniuna', 'Zaldumbide']
# [56]
# 5784080895
# --------------------------------------------------------------------------------

# %%
list(listas.find())
# Out:
# [{'_id': ObjectId('61e8a407535ef3b5ef49e837'),
#   'Nombres_Completos': ['Dustin', 'Kevin'],
#   'Apellidos_Completos': ['Escobar', 'Zaldumbide'],
#   'Edad:': [58],
#   'Cedula:': 6430061808},
#  {'_id': ObjectId('61e8a407535ef3b5ef49e838'),
#   'Nombres_Completos': ['Paul', 'Dustin'],
#   'Apellidos_Completos': ['Pinanjota', 'Espinoza'],
#   'Edad:': [38],
#   'Cedula:': 2171309769},
#  {'_id': ObjectId('61e8a407535ef3b5ef49e839'),
#   'Nombres_Completos': ['Miguel', 'Luis'],
#   'Apellidos_Completos': ['Chavez', 'Guaniuna'],
#   'Edad:': [65],
#   'Cedula:': 4796520336},
#  {'_id': ObjectId('61e8a407535ef3b5ef49e83a'),
#   'Nombres_Completos': ['Steven', 'Jorge'],
#   'Apellidos_Completos': ['Zaldumbide', 'Muzo'],
#   'Edad:': [38],
#   'Cedula:': 8341931448},
#  {'_id': ObjectId('61e8a407535ef3b5ef49e83b'),
#   'Nombres_Completos': ['Paula', 'Luis'],
#   'Apellidos_Completos': ['Guaniuna', 'Zaldumbide'],
#   'Edad:': [56],
#   'Cedula:': 5784080895}]

# %%
pip install pymongo[srv]
# Out:
# Defaulting to user installation because normal site-packages is not writeable
# Requirement already satisfied: pymongo[srv] in c:\users\miguel\appdata\roaming\python\python310\site-packages (4.0.1)
# Requirement already satisfied: dnspython<3.0.0,>=1.16.0 in c:\users\miguel\appdata\roaming\python\python310\site-packages (from pymongo[srv]) (2.2.0)
# Note: you may need to restart the kernel to use updated packages.

# %%
from pymongo import MongoClient
from pymongo.errors import ConnectionFailure

client = MongoClient('mongodb+srv://miguel:miguel@cluster0.ed8kj.mongodb.net/test')
#db.create_collection("clasemongodb")
db = client["clasemongodb"]

listas= db.listas

import numpy as np
import random

print("LISTADO DE CIUDADANOS")
nombres=["Luis","Miguel","Kevin","Dustin","Paula","Steven","Paul","Jorge","Ricardo","Eduardo"]
apellidos=["Muzo","Chavez","Pinanjota","Perez","Zambrano","Zaldumbide","Guaniuna","Espinoza","Escobar","Monteros"]


k=int(input("INGRESE N CIUDADANOS"))

for i in range(k):
    a = np.random.randint(low=1, high=1000000009, size=1).tolist()
    
    edad = np.random.randint(low=18, high=80, size=1).tolist()

    

    nom_C=[]
    ape_C=[]
    
    
    for i in range (2):
        n=np.random.randint(0,9)
        nom_C.append(nombres[n])

    print(nom_C)
    
    


    for i in range (2):
        n=np.random.randint(0,9)
        ape_C.append(apellidos[n])
        
    print(ape_C)
    print(edad)
    
    p=a[0]*9
    print(p)

    
    print("--------------------------------------------------------------------------------")
    
    
    script=[{'Nombres_Completos':nom_C,'Apellidos_Completos':ape_C,'Edad:':edad,'Cedula:':p}]
    
    listas.insert_many(script)
# Out:
# LISTADO DE CIUDADANOS
# INGRESE N CIUDADANOS10
# ['Luis', 'Paula']
# ['Espinoza', 'Zambrano']
# [19]
# 6498521361
# --------------------------------------------------------------------------------
# ['Dustin', 'Steven']
# ['Chavez', 'Zambrano']
# [34]
# 7483906620
# --------------------------------------------------------------------------------
# ['Miguel', 'Paula']
# ['Muzo', 'Zaldumbide']
# [20]
# 2264145903
# --------------------------------------------------------------------------------
# ['Miguel', 'Jorge']
# ['Chavez', 'Zaldumbide']
# [51]
# 3321944865
# --------------------------------------------------------------------------------
# ['Paul', 'Kevin']
# ['Zambrano', 'Perez']
# [72]
# 6613922295
# --------------------------------------------------------------------------------
# ['Paula', 'Ricardo']
# ['Perez', 'Espinoza']
# [21]
# 6127873965
# --------------------------------------------------------------------------------
# ['Luis', 'Dustin']
# ['Zambrano', 'Zaldumbide']
# [21]
# 7119134424
# --------------------------------------------------------------------------------
# ['Ricardo', 'Jorge']
# ['Zambrano', 'Escobar']
# [60]
# 2049341409
# --------------------------------------------------------------------------------
# ['Jorge', 'Dustin']
# ['Guaniuna', 'Pinanjota']
# [69]
# 917092971
# --------------------------------------------------------------------------------
# ['Luis', 'Dustin']
# ['Pinanjota', 'Pinanjota']
# [53]
# 6337188153
# --------------------------------------------------------------------------------

# %%
list(listas.find())
# Out:
# [{'_id': ObjectId('61e8b1dffe14bd496ab01c17'),
#   'Nombres_Completos': ['Luis', 'Paula'],
#   'Apellidos_Completos': ['Espinoza', 'Zambrano'],
#   'Edad:': [19],
#   'Cedula:': 6498521361},
#  {'_id': ObjectId('61e8b1e0fe14bd496ab01c18'),
#   'Nombres_Completos': ['Dustin', 'Steven'],
#   'Apellidos_Completos': ['Chavez', 'Zambrano'],
#   'Edad:': [34],
#   'Cedula:': 7483906620},
#  {'_id': ObjectId('61e8b1e0fe14bd496ab01c19'),
#   'Nombres_Completos': ['Miguel', 'Paula'],
#   'Apellidos_Completos': ['Muzo', 'Zaldumbide'],
#   'Edad:': [20],
#   'Cedula:': 2264145903},
#  {'_id': ObjectId('61e8b1e0fe14bd496ab01c1a'),
#   'Nombres_Completos': ['Miguel', 'Jorge'],
#   'Apellidos_Completos': ['Chavez', 'Zaldumbide'],
#   'Edad:': [51],
#   'Cedula:': 3321944865},
#  {'_id': ObjectId('61e8b1e0fe14bd496ab01c1b'),
#   'Nombres_Completos': ['Paul', 'Kevin'],
#   'Apellidos_Completos': ['Zambrano', 'Perez'],
#   'Edad:': [72],
#   'Cedula:': 6613922295},
#  {'_id': ObjectId('61e8b1e0fe14bd496ab01c1c'),
#   'Nombres_Completos': ['Paula', 'Ricardo'],
#   'Apellidos_Completos': ['Perez', 'Espinoza'],
#   'Edad:': [21],
#   'Cedula:': 6127873965},
#  {'_id': ObjectId('61e8b1e0fe14bd496ab01c1d'),
#   'Nombres_Completos': ['Luis', 'Dustin'],
#   'Apellidos_Completos': ['Zambrano', 'Zaldumbide'],
#   'Edad:': [21],
#   'Cedula:': 7119134424},
#  {'_id': ObjectId('61e8b1e0fe14bd496ab01c1e'),
#   'Nombres_Completos': ['Ricardo', 'Jorge'],
#   'Apellidos_Completos': ['Zambrano', 'Escobar'],
#   'Edad:': [60],
#   'Cedula:': 2049341409},
#  {'_id': ObjectId('61e8b1e0fe14bd496ab01c1f'),
#   'Nombres_Completos': ['Jorge', 'Dustin'],
#   'Apellidos_Completos': ['Guaniuna', 'Pinanjota'],
#   'Edad:': [69],
#   'Cedula:': 917092971},
#  {'_id': ObjectId('61e8b1e0fe14bd496ab01c20'),
#   'Nombres_Completos': ['Luis', 'Dustin'],
#   'Apellidos_Completos': ['Pinanjota', 'Pinanjota'],
#   'Edad:': [53],
#   'Cedula:': 6337188153},
#  {'_id': ObjectId('61e8b1fdf26822fe6b7bcc91'),
#   'Nombres_Completos': ['Jorge', 'Steven'],
#   'Apellidos_Completos': ['Escobar', 'Chavez'],
#   'Edad:': [44],
#   'Cedula:': 4157538336},
#  {'_id': ObjectId('61e8b1fdf26822fe6b7bcc92'),
#   'Nombres_Completos': ['Ricardo', 'Kevin'],
#   'Apellidos_Completos': ['Zambrano', 'Perez'],
#   'Edad:': [78],
#   'Cedula:': 6381893979},
#  {'_id': ObjectId('61e8b1fdf26822fe6b7bcc93'),
#   'Nombres_Completos': ['Paul', 'Luis'],
#   'Apellidos_Completos': ['Pinanjota', 'Zambrano'],
#   'Edad:': [32],
#   'Cedula:': 2215246455},
#  {'_id': ObjectId('61e8b1fef26822fe6b7bcc94'),
#   'Nombres_Completos': ['Luis', 'Steven'],
#   'Apellidos_Completos': ['Pinanjota', 'Zaldumbide'],
#   'Edad:': [41],
#   'Cedula:': 3125914686},
#  {'_id': ObjectId('61e8b1fef26822fe6b7bcc95'),
#   'Nombres_Completos': ['Dustin', 'Steven'],
#   'Apellidos_Completos': ['Zaldumbide', 'Escobar'],
#   'Edad:': [38],
#   'Cedula:': 3682612125},
#  {'_id': ObjectId('61e8b1fef26822fe6b7bcc96'),
#   'Nombres_Completos': ['Paula', 'Kevin'],
#   'Apellidos_Completos': ['Zambrano', 'Muzo'],
#   'Edad:': [58],
#   'Cedula:': 2863057383},
#  {'_id': ObjectId('61e8b1fef26822fe6b7bcc97'),
#   'Nombres_Completos': ['Ricardo', 'Steven'],
#   'Apellidos_Completos': ['Zaldumbide', 'Escobar'],
#   'Edad:': [62],
#   'Cedula:': 5666608152},
#  {'_id': ObjectId('61e8b1fef26822fe6b7bcc98'),
#   'Nombres_Completos': ['Kevin', 'Steven'],
#   'Apellidos_Completos': ['Muzo', 'Zambrano'],
#   'Edad:': [20],
#   'Cedula:': 4445562879},
#  {'_id': ObjectId('61e8b1fef26822fe6b7bcc99'),
#   'Nombres_Completos': ['Steven', 'Paul'],
#   'Apellidos_Completos': ['Espinoza', 'Pinanjota'],
#   'Edad:': [71],
#   'Cedula:': 4206632400},
#  {'_id': ObjectId('61e8b1fef26822fe6b7bcc9a'),
#   'Nombres_Completos': ['Kevin', 'Miguel'],
#   'Apellidos_Completos': ['Perez', 'Chavez'],
#   'Edad:': [30],
#   'Cedula:': 6360669846},
#  {'_id': ObjectId('61e8b1fef26822fe6b7bcc9b'),
#   'Nombres_Completos': ['Ricardo', 'Steven'],
#   'Apellidos_Completos': ['Chavez', 'Muzo'],
#   'Edad:': [30],
#   'Cedula:': 2138552181},
#  {'_id': ObjectId('61e8b1fef26822fe6b7bcc9c'),
#   'Nombres_Completos': ['Paula', 'Jorge'],
#   'Apellidos_Completos': ['Zaldumbide', 'Espinoza'],
#   'Edad:': [46],
#   'Cedula:': 8302546845},
#  {'_id': ObjectId('61e8b1fef26822fe6b7bcc9d'),
#   'Nombres_Completos': ['Miguel', 'Steven'],
#   'Apellidos_Completos': ['Guaniuna', 'Perez'],
#   'Edad:': [56],
#   'Cedula:': 3011840109},
#  {'_id': ObjectId('61e8b1fff26822fe6b7bcc9e'),
#   'Nombres_Completos': ['Paul', 'Luis'],
#   'Apellidos_Completos': ['Zaldumbide', 'Espinoza'],
#   'Edad:': [19],
#   'Cedula:': 6413494365},
#  {'_id': ObjectId('61e8b1fff26822fe6b7bcc9f'),
#   'Nombres_Completos': ['Paula', 'Luis'],
#   'Apellidos_Completos': ['Pinanjota', 'Perez'],
#   'Edad:': [46],
#   'Cedula:': 7872606693},
#  {'_id': ObjectId('61e8b1fff26822fe6b7bcca0'),
#   'Nombres_Completos': ['Dustin', 'Kevin'],
#   'Apellidos_Completos': ['Zambrano', 'Muzo'],
#   'Edad:': [70],
#   'Cedula:': 249690294},
#  {'_id': ObjectId('61e8b1fff26822fe6b7bcca1'),
#   'Nombres_Completos': ['Steven', 'Ricardo'],
#   'Apellidos_Completos': ['Escobar', 'Zaldumbide'],
#   'Edad:': [24],
#   'Cedula:': 4272947316},
#  {'_id': ObjectId('61e8b1fff26822fe6b7bcca2'),
#   'Nombres_Completos': ['Kevin', 'Luis'],
#   'Apellidos_Completos': ['Guaniuna', 'Perez'],
#   'Edad:': [60],
#   'Cedula:': 8316531918},
#  {'_id': ObjectId('61e8b1fff26822fe6b7bcca3'),
#   'Nombres_Completos': ['Dustin', 'Luis'],
#   'Apellidos_Completos': ['Chavez', 'Guaniuna'],
#   'Edad:': [18],
#   'Cedula:': 8363999601},
#  {'_id': ObjectId('61e8b1fff26822fe6b7bcca4'),
#   'Nombres_Completos': ['Kevin', 'Luis'],
#   'Apellidos_Completos': ['Chavez', 'Guaniuna'],
#   'Edad:': [61],
#   'Cedula:': 6193505385},
#  {'_id': ObjectId('61e8b1fff26822fe6b7bcca5'),
#   'Nombres_Completos': ['Luis', 'Jorge'],
#   'Apellidos_Completos': ['Guaniuna', 'Perez'],
#   'Edad:': [38],
#   'Cedula:': 7303549041},
#  {'_id': ObjectId('61e8b1fff26822fe6b7bcca6'),
#   'Nombres_Completos': ['Kevin', 'Paula'],
#   'Apellidos_Completos': ['Zambrano', 'Chavez'],
#   'Edad:': [33],
#   'Cedula:': 5165566308},
#  {'_id': ObjectId('61e8b200f26822fe6b7bcca7'),
#   'Nombres_Completos': ['Jorge', 'Paula'],
#   'Apellidos_Completos': ['Escobar', 'Perez'],
#   'Edad:': [23],
#   'Cedula:': 2731918563},
#  {'_id': ObjectId('61e8b200f26822fe6b7bcca8'),
#   'Nombres_Completos': ['Paul', 'Paula'],
#   'Apellidos_Completos': ['Zaldumbide', 'Muzo'],
#   'Edad:': [32],
#   'Cedula:': 4675642623},
#  {'_id': ObjectId('61e8b200f26822fe6b7bcca9'),
#   'Nombres_Completos': ['Ricardo', 'Ricardo'],
#   'Apellidos_Completos': ['Guaniuna', 'Pinanjota'],
#   'Edad:': [70],
#   'Cedula:': 6661056420},
#  {'_id': ObjectId('61e8b200f26822fe6b7bccaa'),
#   'Nombres_Completos': ['Miguel', 'Steven'],
#   'Apellidos_Completos': ['Espinoza', 'Chavez'],
#   'Edad:': [74],
#   'Cedula:': 4944725280},
#  {'_id': ObjectId('61e8b200f26822fe6b7bccab'),
#   'Nombres_Completos': ['Steven', 'Paula'],
#   'Apellidos_Completos': ['Pinanjota', 'Espinoza'],
#   'Edad:': [26],
#   'Cedula:': 5201896086},
#  {'_id': ObjectId('61e8b200f26822fe6b7bccac'),
#   'Nombres_Completos': ['Paula', 'Steven'],
#   'Apellidos_Completos': ['Guaniuna', 'Zaldumbide'],
#   'Edad:': [62],
#   'Cedula:': 387483219},
#  {'_id': ObjectId('61e8b200f26822fe6b7bccad'),
#   'Nombres_Completos': ['Paul', 'Miguel'],
#   'Apellidos_Completos': ['Chavez', 'Escobar'],
#   'Edad:': [79],
#   'Cedula:': 6742745919},
#  {'_id': ObjectId('61e8b200f26822fe6b7bccae'),
#   'Nombres_Completos': ['Ricardo', 'Paula'],
#   'Apellidos_Completos': ['Muzo', 'Pinanjota'],
#   'Edad:': [63],
#   'Cedula:': 3123265284},
#  {'_id': ObjectId('61e8b200f26822fe6b7bccaf'),
#   'Nombres_Completos': ['Luis', 'Kevin'],
#   'Apellidos_Completos': ['Chavez', 'Espinoza'],
#   'Edad:': [33],
#   'Cedula:': 8020001043},
#  {'_id': ObjectId('61e8b201f26822fe6b7bccb0'),
#   'Nombres_Completos': ['Paula', 'Miguel'],
#   'Apellidos_Completos': ['Muzo', 'Pinanjota'],
#   'Edad:': [32],
#   'Cedula:': 8816089428},
#  {'_id': ObjectId('61e8b201f26822fe6b7bccb1'),
#   'Nombres_Completos': ['Steven', 'Paula'],
#   'Apellidos_Completos': ['Escobar', 'Espinoza'],
#   'Edad:': [48],
#   'Cedula:': 4706606322},
#  {'_id': ObjectId('61e8b201f26822fe6b7bccb2'),
#   'Nombres_Completos': ['Luis', 'Miguel'],
#   'Apellidos_Completos': ['Guaniuna', 'Muzo'],
#   'Edad:': [65],
#   'Cedula:': 4697973144},
#  {'_id': ObjectId('61e8b201f26822fe6b7bccb3'),
#   'Nombres_Completos': ['Kevin', 'Kevin'],
#   'Apellidos_Completos': ['Chavez', 'Perez'],
#   'Edad:': [29],
#   'Cedula:': 5490840735},
#  {'_id': ObjectId('61e8b201f26822fe6b7bccb4'),
#   'Nombres_Completos': ['Kevin', 'Paula'],
#   'Apellidos_Completos': ['Guaniuna', 'Guaniuna'],
#   'Edad:': [75],
#   'Cedula:': 525783276},
#  {'_id': ObjectId('61e8b201f26822fe6b7bccb5'),
#   'Nombres_Completos': ['Miguel', 'Paula'],
#   'Apellidos_Completos': ['Chavez', 'Pinanjota'],
#   'Edad:': [77],
#   'Cedula:': 2442496158},
#  {'_id': ObjectId('61e8b201f26822fe6b7bccb6'),
#   'Nombres_Completos': ['Ricardo', 'Paula'],
#   'Apellidos_Completos': ['Guaniuna', 'Zaldumbide'],
#   'Edad:': [79],
#   'Cedula:': 4041643077},
#  {'_id': ObjectId('61e8b201f26822fe6b7bccb7'),
#   'Nombres_Completos': ['Steven', 'Jorge'],
#   'Apellidos_Completos': ['Escobar', 'Escobar'],
#   'Edad:': [72],
#   'Cedula:': 7611590016},
#  {'_id': ObjectId('61e8b201f26822fe6b7bccb8'),
#   'Nombres_Completos': ['Kevin', 'Ricardo'],
#   'Apellidos_Completos': ['Perez', 'Muzo'],
#   'Edad:': [72],
#   'Cedula:': 569283597},
#  {'_id': ObjectId('61e8b202f26822fe6b7bccb9'),
#   'Nombres_Completos': ['Dustin', 'Luis'],
#   'Apellidos_Completos': ['Guaniuna', 'Perez'],
#   'Edad:': [18],
#   'Cedula:': 5586610095},
#  {'_id': ObjectId('61e8b202f26822fe6b7bccba'),
#   'Nombres_Completos': ['Steven', 'Luis'],
#   'Apellidos_Completos': ['Muzo', 'Escobar'],
#   'Edad:': [60],
#   'Cedula:': 1225095399},
#  {'_id': ObjectId('61e8b202f26822fe6b7bccbb'),
#   'Nombres_Completos': ['Jorge', 'Steven'],
#   'Apellidos_Completos': ['Zambrano', 'Zambrano'],
#   'Edad:': [34],
#   'Cedula:': 6547198968},
#  {'_id': ObjectId('61e8b202f26822fe6b7bccbc'),
#   'Nombres_Completos': ['Dustin', 'Steven'],
#   'Apellidos_Completos': ['Escobar', 'Zaldumbide'],
#   'Edad:': [26],
#   'Cedula:': 8402501079},
#  {'_id': ObjectId('61e8b202f26822fe6b7bccbd'),
#   'Nombres_Completos': ['Dustin', 'Kevin'],
#   'Apellidos_Completos': ['Perez', 'Espinoza'],
#   'Edad:': [32],
#   'Cedula:': 708991182},
#  {'_id': ObjectId('61e8b202f26822fe6b7bccbe'),
#   'Nombres_Completos': ['Luis', 'Paul'],
#   'Apellidos_Completos': ['Zaldumbide', 'Guaniuna'],
#   'Edad:': [22],
#   'Cedula:': 887117472},
#  {'_id': ObjectId('61e8b202f26822fe6b7bccbf'),
#   'Nombres_Completos': ['Luis', 'Miguel'],
#   'Apellidos_Completos': ['Pinanjota', 'Chavez'],
#   'Edad:': [36],
#   'Cedula:': 5584400082},
#  {'_id': ObjectId('61e8b202f26822fe6b7bccc0'),
#   'Nombres_Completos': ['Dustin', 'Luis'],
#   'Apellidos_Completos': ['Zaldumbide', 'Pinanjota'],
#   'Edad:': [74],
#   'Cedula:': 6844183110},
#  {'_id': ObjectId('61e8b202f26822fe6b7bccc1'),
#   'Nombres_Completos': ['Miguel', 'Jorge'],
#   'Apellidos_Completos': ['Espinoza', 'Zambrano'],
#   'Edad:': [29],
#   'Cedula:': 60356088},
#  {'_id': ObjectId('61e8b202f26822fe6b7bccc2'),
#   'Nombres_Completos': ['Kevin', 'Kevin'],
#   'Apellidos_Completos': ['Pinanjota', 'Muzo'],
#   'Edad:': [20],
#   'Cedula:': 8747684397},
#  {'_id': ObjectId('61e8b203f26822fe6b7bccc3'),
#   'Nombres_Completos': ['Luis', 'Paul'],
#   'Apellidos_Completos': ['Zaldumbide', 'Guaniuna'],
#   'Edad:': [79],
#   'Cedula:': 1228009752},
#  {'_id': ObjectId('61e8b203f26822fe6b7bccc4'),
#   'Nombres_Completos': ['Luis', 'Paul'],
#   'Apellidos_Completos': ['Escobar', 'Muzo'],
#   'Edad:': [55],
#   'Cedula:': 2788486488},
#  {'_id': ObjectId('61e8b203f26822fe6b7bccc5'),
#   'Nombres_Completos': ['Jorge', 'Kevin'],
#   'Apellidos_Completos': ['Chavez', 'Zaldumbide'],
#   'Edad:': [43],
#   'Cedula:': 1357624404},
#  {'_id': ObjectId('61e8b203f26822fe6b7bccc6'),
#   'Nombres_Completos': ['Ricardo', 'Paula'],
#   'Apellidos_Completos': ['Muzo', 'Guaniuna'],
#   'Edad:': [56],
#   'Cedula:': 6350682033},
#  {'_id': ObjectId('61e8b203f26822fe6b7bccc7'),
#   'Nombres_Completos': ['Jorge', 'Paul'],
#   'Apellidos_Completos': ['Muzo', 'Pinanjota'],
#   'Edad:': [67],
#   'Cedula:': 5289780366},
#  {'_id': ObjectId('61e8b247f26822fe6b7bccca'),
#   'Nombres_Completos': ['Miguel', 'Jorge'],
#   'Apellidos_Completos': ['Escobar', 'Pinanjota'],
#   'Edad:': [75],
#   'Cedula:': 2002788513},
#  {'_id': ObjectId('61e8b248f26822fe6b7bcccb'),
#   'Nombres_Completos': ['Kevin', 'Miguel'],
#   'Apellidos_Completos': ['Pinanjota', 'Muzo'],
#   'Edad:': [74],
#   'Cedula:': 8475143679},
#  {'_id': ObjectId('61e8b248f26822fe6b7bcccc'),
#   'Nombres_Completos': ['Luis', 'Miguel'],
#   'Apellidos_Completos': ['Perez', 'Espinoza'],
#   'Edad:': [68],
#   'Cedula:': 547455969},
#  {'_id': ObjectId('61e8b248f26822fe6b7bcccd'),
#   'Nombres_Completos': ['Paula', 'Paul'],
#   'Apellidos_Completos': ['Espinoza', 'Muzo'],
#   'Edad:': [45],
#   'Cedula:': 5312365353},
#  {'_id': ObjectId('61e8b248f26822fe6b7bccce'),
#   'Nombres_Completos': ['Paul', 'Dustin'],
#   'Apellidos_Completos': ['Perez', 'Muzo'],
#   'Edad:': [45],
#   'Cedula:': 5554268289},
#  {'_id': ObjectId('61e8b248f26822fe6b7bcccf'),
#   'Nombres_Completos': ['Steven', 'Ricardo'],
#   'Apellidos_Completos': ['Perez', 'Zambrano'],
#   'Edad:': [23],
#   'Cedula:': 6371339733},
#  {'_id': ObjectId('61e8b248f26822fe6b7bccd0'),
#   'Nombres_Completos': ['Paula', 'Kevin'],
#   'Apellidos_Completos': ['Zaldumbide', 'Guaniuna'],
#   'Edad:': [51],
#   'Cedula:': 2304274131},
#  {'_id': ObjectId('61e8b248f26822fe6b7bccd1'),
#   'Nombres_Completos': ['Ricardo', 'Miguel'],
#   'Apellidos_Completos': ['Guaniuna', 'Espinoza'],
#   'Edad:': [50],
#   'Cedula:': 4340867607},
#  {'_id': ObjectId('61e8b249f26822fe6b7bccd2'),
#   'Nombres_Completos': ['Dustin', 'Dustin'],
#   'Apellidos_Completos': ['Guaniuna', 'Guaniuna'],
#   'Edad:': [61],
#   'Cedula:': 7750515249},
#  {'_id': ObjectId('61e8b249f26822fe6b7bccd3'),
#   'Nombres_Completos': ['Paula', 'Miguel'],
#   'Apellidos_Completos': ['Perez', 'Guaniuna'],
#   'Edad:': [23],
#   'Cedula:': 5818288059},
#  {'_id': ObjectId('61e8b249f26822fe6b7bccd4'),
#   'Nombres_Completos': ['Luis', 'Luis'],
#   'Apellidos_Completos': ['Chavez', 'Perez'],
#   'Edad:': [50],
#   'Cedula:': 7988526711},
#  {'_id': ObjectId('61e8b249f26822fe6b7bccd5'),
#   'Nombres_Completos': ['Ricardo', 'Ricardo'],
#   'Apellidos_Completos': ['Espinoza', 'Perez'],
#   'Edad:': [35],
#   'Cedula:': 4685859864},
#  {'_id': ObjectId('61e8b249f26822fe6b7bccd6'),
#   'Nombres_Completos': ['Miguel', 'Paula'],
#   'Apellidos_Completos': ['Zaldumbide', 'Espinoza'],
#   'Edad:': [43],
#   'Cedula:': 7411630743},
#  {'_id': ObjectId('61e8b249f26822fe6b7bccd7'),
#   'Nombres_Completos': ['Ricardo', 'Paul'],
#   'Apellidos_Completos': ['Zambrano', 'Zaldumbide'],
#   'Edad:': [64],
#   'Cedula:': 7317036504},
#  {'_id': ObjectId('61e8b24af26822fe6b7bccd8'),
#   'Nombres_Completos': ['Paul', 'Steven'],
#   'Apellidos_Completos': ['Guaniuna', 'Zambrano'],
#   'Edad:': [43],
#   'Cedula:': 4594657320},
#  {'_id': ObjectId('61e8b24af26822fe6b7bccd9'),
#   'Nombres_Completos': ['Steven', 'Steven'],
#   'Apellidos_Completos': ['Perez', 'Zaldumbide'],
#   'Edad:': [68],
#   'Cedula:': 7317792702},
#  {'_id': ObjectId('61e8b24af26822fe6b7bccda'),
#   'Nombres_Completos': ['Miguel', 'Kevin'],
#   'Apellidos_Completos': ['Guaniuna', 'Zaldumbide'],
#   'Edad:': [52],
#   'Cedula:': 1345344912},
#  {'_id': ObjectId('61e8b24af26822fe6b7bccdb'),
#   'Nombres_Completos': ['Miguel', 'Paul'],
#   'Apellidos_Completos': ['Escobar', 'Espinoza'],
#   'Edad:': [20],
#   'Cedula:': 6294926313},
#  {'_id': ObjectId('61e8b24af26822fe6b7bccdc'),
#   'Nombres_Completos': ['Miguel', 'Ricardo'],
#   'Apellidos_Completos': ['Muzo', 'Zaldumbide'],
#   'Edad:': [41],
#   'Cedula:': 4652379288},
#  {'_id': ObjectId('61e8b24af26822fe6b7bccdd'),
#   'Nombres_Completos': ['Miguel', 'Miguel'],
#   'Apellidos_Completos': ['Escobar', 'Perez'],
#   'Edad:': [65],
#   'Cedula:': 7445192598},
#  {'_id': ObjectId('61e8b24af26822fe6b7bccde'),
#   'Nombres_Completos': ['Paul', 'Ricardo'],
#   'Apellidos_Completos': ['Guaniuna', 'Muzo'],
#   'Edad:': [59],
#   'Cedula:': 8537387508},
#  {'_id': ObjectId('61e8b24af26822fe6b7bccdf'),
#   'Nombres_Completos': ['Kevin', 'Luis'],
#   'Apellidos_Completos': ['Guaniuna', 'Guaniuna'],
#   'Edad:': [22],
#   'Cedula:': 781470432},
#  {'_id': ObjectId('61e8b24af26822fe6b7bcce0'),
#   'Nombres_Completos': ['Ricardo', 'Ricardo'],
#   'Apellidos_Completos': ['Chavez', 'Escobar'],
#   'Edad:': [74],
#   'Cedula:': 3265592256},
#  {'_id': ObjectId('61e8b24bf26822fe6b7bcce1'),
#   'Nombres_Completos': ['Ricardo', 'Paula'],
#   'Apellidos_Completos': ['Chavez', 'Zaldumbide'],
#   'Edad:': [19],
#   'Cedula:': 1657956627},
#  {'_id': ObjectId('61e8b24bf26822fe6b7bcce2'),
#   'Nombres_Completos': ['Dustin', 'Dustin'],
#   'Apellidos_Completos': ['Muzo', 'Zaldumbide'],
#   'Edad:': [38],
#   'Cedula:': 2320580817},
#  {'_id': ObjectId('61e8b24bf26822fe6b7bcce3'),
#   'Nombres_Completos': ['Dustin', 'Dustin'],
#   'Apellidos_Completos': ['Pinanjota', 'Escobar'],
#   'Edad:': [62],
#   'Cedula:': 5138808849},
#  {'_id': ObjectId('61e8b24bf26822fe6b7bcce4'),
#   'Nombres_Completos': ['Kevin', 'Jorge'],
#   'Apellidos_Completos': ['Zambrano', 'Espinoza'],
#   'Edad:': [54],
#   'Cedula:': 3015529974},
#  {'_id': ObjectId('61e8b24bf26822fe6b7bcce5'),
#   'Nombres_Completos': ['Luis', 'Ricardo'],
#   'Apellidos_Completos': ['Guaniuna', 'Muzo'],
#   'Edad:': [30],
#   'Cedula:': 8554709709},
#  {'_id': ObjectId('61e8b24bf26822fe6b7bcce6'),
#   'Nombres_Completos': ['Miguel', 'Miguel'],
#   'Apellidos_Completos': ['Chavez', 'Espinoza'],
#   'Edad:': [31],
#   'Cedula:': 2386035522},
#  {'_id': ObjectId('61e8b24bf26822fe6b7bcce7'),
#   'Nombres_Completos': ['Luis', 'Miguel'],
#   'Apellidos_Completos': ['Escobar', 'Muzo'],
#   'Edad:': [57],
#   'Cedula:': 1035213642},
#  {'_id': ObjectId('61e8b24bf26822fe6b7bcce8'),
#   'Nombres_Completos': ['Dustin', 'Jorge'],
#   'Apellidos_Completos': ['Muzo', 'Espinoza'],
#   'Edad:': [37],
#   'Cedula:': 2637113445},
#  {'_id': ObjectId('61e8b24bf26822fe6b7bcce9'),
#   'Nombres_Completos': ['Miguel', 'Paula'],
#   'Apellidos_Completos': ['Espinoza', 'Pinanjota'],
#   'Edad:': [78],
#   'Cedula:': 707827176},
#  {'_id': ObjectId('61e8b24bf26822fe6b7bccea'),
#   'Nombres_Completos': ['Paul', 'Luis'],
#   'Apellidos_Completos': ['Zambrano', 'Muzo'],
#   'Edad:': [69],
#   'Cedula:': 6279938019},
#  {'_id': ObjectId('61e8b24cf26822fe6b7bcceb'),
#   'Nombres_Completos': ['Ricardo', 'Miguel'],
#   'Apellidos_Completos': ['Zaldumbide', 'Guaniuna'],
#   'Edad:': [68],
#   'Cedula:': 7895970990},
#  {'_id': ObjectId('61e8b24cf26822fe6b7bccec'),
#   'Nombres_Completos': ['Kevin', 'Miguel'],
#   'Apellidos_Completos': ['Muzo', 'Perez'],
#   'Edad:': [52],
#   'Cedula:': 7675875882},
#  {'_id': ObjectId('61e8b24cf26822fe6b7bcced'),
#   'Nombres_Completos': ['Paula', 'Dustin'],
#   'Apellidos_Completos': ['Pinanjota', 'Escobar'],
#   'Edad:': [19],
#   'Cedula:': 5298172875},
#  {'_id': ObjectId('61e8b24cf26822fe6b7bccee'),
#   'Nombres_Completos': ['Ricardo', 'Luis'],
#   'Apellidos_Completos': ['Guaniuna', 'Perez'],
#   'Edad:': [65],
#   'Cedula:': 6858260604},
#  {'_id': ObjectId('61e8b24cf26822fe6b7bccef'),
#   'Nombres_Completos': ['Miguel', 'Miguel'],
#   'Apellidos_Completos': ['Espinoza', 'Escobar'],
#   'Edad:': [19],
#   'Cedula:': 4498537941},
#  {'_id': ObjectId('61e8b24cf26822fe6b7bccf0'),
#   'Nombres_Completos': ['Steven', 'Steven'],
#   'Apellidos_Completos': ['Zaldumbide', 'Chavez'],
#   'Edad:': [74],
#   'Cedula:': 5083191549},
#  {'_id': ObjectId('61e8b24cf26822fe6b7bccf1'),
#   'Nombres_Completos': ['Steven', 'Luis'],
#   'Apellidos_Completos': ['Zaldumbide', 'Guaniuna'],
#   'Edad:': [73],
#   'Cedula:': 7481526390},
#  {'_id': ObjectId('61e8b24cf26822fe6b7bccf2'),
#   'Nombres_Completos': ['Kevin', 'Paul'],
#   'Apellidos_Completos': ['Pinanjota', 'Zaldumbide'],
#   'Edad:': [64],
#   'Cedula:': 85975011},
#  {'_id': ObjectId('61e8b24cf26822fe6b7bccf3'),
#   'Nombres_Completos': ['Miguel', 'Steven'],
#   'Apellidos_Completos': ['Guaniuna', 'Escobar'],
#   'Edad:': [70],
#   'Cedula:': 2234708622},
#  {'_id': ObjectId('61e8b24df26822fe6b7bccf4'),
#   'Nombres_Completos': ['Dustin', 'Paula'],
#   'Apellidos_Completos': ['Espinoza', 'Muzo'],
#   'Edad:': [79],
#   'Cedula:': 5993357769},
#  {'_id': ObjectId('61e8b24df26822fe6b7bccf5'),
#   'Nombres_Completos': ['Ricardo', 'Ricardo'],
#   'Apellidos_Completos': ['Perez', 'Chavez'],
#   'Edad:': [40],
#   'Cedula:': 2823279138},
#  {'_id': ObjectId('61e8b24df26822fe6b7bccf6'),
#   'Nombres_Completos': ['Paul', 'Kevin'],
#   'Apellidos_Completos': ['Chavez', 'Muzo'],
#   'Edad:': [65],
#   'Cedula:': 2945710953},
#  {'_id': ObjectId('61e8b24df26822fe6b7bccf7'),
#   'Nombres_Completos': ['Jorge', 'Miguel'],
#   'Apellidos_Completos': ['Muzo', 'Zambrano'],
#   'Edad:': [63],
#   'Cedula:': 3074489262},
#  {'_id': ObjectId('61e8b24df26822fe6b7bccf8'),
#   'Nombres_Completos': ['Paula', 'Paul'],
#   'Apellidos_Completos': ['Zaldumbide', 'Muzo'],
#   'Edad:': [60],
#   'Cedula:': 991029987},
#  {'_id': ObjectId('61e8b24df26822fe6b7bccf9'),
#   'Nombres_Completos': ['Miguel', 'Luis'],
#   'Apellidos_Completos': ['Chavez', 'Muzo'],
#   'Edad:': [68],
#   'Cedula:': 1891636209},
#  {'_id': ObjectId('61e8b24df26822fe6b7bccfa'),
#   'Nombres_Completos': ['Jorge', 'Jorge'],
#   'Apellidos_Completos': ['Zambrano', 'Zaldumbide'],
#   'Edad:': [29],
#   'Cedula:': 8408888217},
#  {'_id': ObjectId('61e8b24df26822fe6b7bccfb'),
#   'Nombres_Completos': ['Ricardo', 'Luis'],
#   'Apellidos_Completos': ['Muzo', 'Escobar'],
#   'Edad:': [79],
#   'Cedula:': 1994732478},
#  {'_id': ObjectId('61e8b24df26822fe6b7bccfc'),
#   'Nombres_Completos': ['Miguel', 'Miguel'],
#   'Apellidos_Completos': ['Guaniuna', 'Chavez'],
#   'Edad:': [61],
#   'Cedula:': 7944434109},
#  {'_id': ObjectId('61e8b24ef26822fe6b7bccfd'),
#   'Nombres_Completos': ['Dustin', 'Ricardo'],
#   'Apellidos_Completos': ['Escobar', 'Zambrano'],
#   'Edad:': [23],
#   'Cedula:': 1998344781},
#  {'_id': ObjectId('61e8b24ef26822fe6b7bccfe'),
#   'Nombres_Completos': ['Ricardo', 'Ricardo'],
#   'Apellidos_Completos': ['Pinanjota', 'Perez'],
#   'Edad:': [28],
#   'Cedula:': 1493277840},
#  {'_id': ObjectId('61e8b24ef26822fe6b7bccff'),
#   'Nombres_Completos': ['Paula', 'Kevin'],
#   'Apellidos_Completos': ['Espinoza', 'Chavez'],
#   'Edad:': [52],
#   'Cedula:': 6457060296},
#  {'_id': ObjectId('61e8b24ef26822fe6b7bcd00'),
#   'Nombres_Completos': ['Jorge', 'Ricardo'],
#   'Apellidos_Completos': ['Zaldumbide', 'Espinoza'],
#   'Edad:': [39],
#   'Cedula:': 1807900848},
#  {'_id': ObjectId('61e8b24ef26822fe6b7bcd01'),
#   'Nombres_Completos': ['Steven', 'Jorge'],
#   'Apellidos_Completos': ['Zambrano', 'Muzo'],
#   'Edad:': [45],
#   'Cedula:': 2890159803},
#  {'_id': ObjectId('61e8b24ef26822fe6b7bcd02'),
#   'Nombres_Completos': ['Jorge', 'Paul'],
#   'Apellidos_Completos': ['Chavez', 'Pinanjota'],
#   'Edad:': [52],
#   'Cedula:': 8165370348},
#  {'_id': ObjectId('61e8b24ef26822fe6b7bcd03'),
#   'Nombres_Completos': ['Paul', 'Kevin'],
#   'Apellidos_Completos': ['Chavez', 'Guaniuna'],
#   'Edad:': [79],
#   'Cedula:': 4860587619},
#  {'_id': ObjectId('61e8b24ef26822fe6b7bcd04'),
#   'Nombres_Completos': ['Kevin', 'Kevin'],
#   'Apellidos_Completos': ['Pinanjota', 'Guaniuna'],
#   'Edad:': [46],
#   'Cedula:': 4316307399},
#  {'_id': ObjectId('61e8b24ef26822fe6b7bcd05'),
#   'Nombres_Completos': ['Steven', 'Dustin'],
#   'Apellidos_Completos': ['Guaniuna', 'Perez'],
#   'Edad:': [72],
#   'Cedula:': 6953775453},
#  {'_id': ObjectId('61e8b24ff26822fe6b7bcd06'),
#   'Nombres_Completos': ['Dustin', 'Paul'],
#   'Apellidos_Completos': ['Zaldumbide', 'Espinoza'],
#   'Edad:': [28],
#   'Cedula:': 6532717365},
#  {'_id': ObjectId('61e8b24ff26822fe6b7bcd07'),
#   'Nombres_Completos': ['Paula', 'Kevin'],
#   'Apellidos_Completos': ['Muzo', 'Perez'],
#   'Edad:': [66],
#   'Cedula:': 2501753715},
#  {'_id': ObjectId('61e8b24ff26822fe6b7bcd08'),
#   'Nombres_Completos': ['Dustin', 'Paula'],
#   'Apellidos_Completos': ['Chavez', 'Guaniuna'],
#   'Edad:': [25],
#   'Cedula:': 1868170923},
#  {'_id': ObjectId('61e8b24ff26822fe6b7bcd09'),
#   'Nombres_Completos': ['Luis', 'Paul'],
#   'Apellidos_Completos': ['Espinoza', 'Muzo'],
#   'Edad:': [72],
#   'Cedula:': 5803652322},
#  {'_id': ObjectId('61e8b24ff26822fe6b7bcd0a'),
#   'Nombres_Completos': ['Steven', 'Dustin'],
#   'Apellidos_Completos': ['Pinanjota', 'Zambrano'],
#   'Edad:': [43],
#   'Cedula:': 2104203726},
#  {'_id': ObjectId('61e8b24ff26822fe6b7bcd0b'),
#   'Nombres_Completos': ['Steven', 'Miguel'],
#   'Apellidos_Completos': ['Guaniuna', 'Guaniuna'],
#   'Edad:': [69],
#   'Cedula:': 6387276159},
#  {'_id': ObjectId('61e8b24ff26822fe6b7bcd0c'),
#   'Nombres_Completos': ['Miguel', 'Dustin'],
#   'Apellidos_Completos': ['Chavez', 'Zaldumbide'],
#   'Edad:': [38],
#   'Cedula:': 3047981796},
#  {'_id': ObjectId('61e8b24ff26822fe6b7bcd0d'),
#   'Nombres_Completos': ['Steven', 'Dustin'],
#   'Apellidos_Completos': ['Perez', 'Chavez'],
#   'Edad:': [43],
#   'Cedula:': 2334591936},
#  {'_id': ObjectId('61e8b24ff26822fe6b7bcd0e'),
#   'Nombres_Completos': ['Luis', 'Kevin'],
#   'Apellidos_Completos': ['Guaniuna', 'Escobar'],
#   'Edad:': [18],
#   'Cedula:': 2266896348},
#  {'_id': ObjectId('61e8b250f26822fe6b7bcd0f'),
#   'Nombres_Completos': ['Steven', 'Luis'],
#   'Apellidos_Completos': ['Muzo', 'Espinoza'],
#   'Edad:': [47],
#   'Cedula:': 4142911878},
#  {'_id': ObjectId('61e8b250f26822fe6b7bcd10'),
#   'Nombres_Completos': ['Miguel', 'Ricardo'],
#   'Apellidos_Completos': ['Pinanjota', 'Guaniuna'],
#   'Edad:': [22],
#   'Cedula:': 2216986173},
#  {'_id': ObjectId('61e8b250f26822fe6b7bcd11'),
#   'Nombres_Completos': ['Miguel', 'Ricardo'],
#   'Apellidos_Completos': ['Chavez', 'Perez'],
#   'Edad:': [51],
#   'Cedula:': 5077782054},
#  {'_id': ObjectId('61e8b250f26822fe6b7bcd12'),
#   'Nombres_Completos': ['Steven', 'Paula'],
#   'Apellidos_Completos': ['Guaniuna', 'Chavez'],
#   'Edad:': [73],
#   'Cedula:': 3321741708},
#  {'_id': ObjectId('61e8b250f26822fe6b7bcd13'),
#   'Nombres_Completos': ['Miguel', 'Paula'],
#   'Apellidos_Completos': ['Chavez', 'Guaniuna'],
#   'Edad:': [59],
#   'Cedula:': 3582810774},
#  {'_id': ObjectId('61e8b250f26822fe6b7bcd14'),
#   'Nombres_Completos': ['Miguel', 'Paul'],
#   'Apellidos_Completos': ['Perez', 'Guaniuna'],
#   'Edad:': [43],
#   'Cedula:': 3125832741},
#  {'_id': ObjectId('61e8b250f26822fe6b7bcd15'),
#   'Nombres_Completos': ['Steven', 'Miguel'],
#   'Apellidos_Completos': ['Guaniuna', 'Zaldumbide'],
#   'Edad:': [66],
#   'Cedula:': 153398052},
#  {'_id': ObjectId('61e8b250f26822fe6b7bcd16'),
#   'Nombres_Completos': ['Dustin', 'Paul'],
#   'Apellidos_Completos': ['Pinanjota', 'Guaniuna'],
#   'Edad:': [18],
#   'Cedula:': 5919123402},
#  {'_id': ObjectId('61e8b250f26822fe6b7bcd17'),
#   'Nombres_Completos': ['Miguel', 'Paula'],
#   'Apellidos_Completos': ['Perez', 'Guaniuna'],
#   'Edad:': [33],
#   'Cedula:': 3978979893},
#  {'_id': ObjectId('61e8b251f26822fe6b7bcd18'),
#   'Nombres_Completos': ['Dustin', 'Paul'],
#   'Apellidos_Completos': ['Zambrano', 'Guaniuna'],
#   'Edad:': [53],
#   'Cedula:': 4237927830},
#  {'_id': ObjectId('61e8b251f26822fe6b7bcd19'),
#   'Nombres_Completos': ['Paula', 'Miguel'],
#   'Apellidos_Completos': ['Muzo', 'Escobar'],
#   'Edad:': [65],
#   'Cedula:': 2256543909},
#  {'_id': ObjectId('61e8b251f26822fe6b7bcd1a'),
#   'Nombres_Completos': ['Miguel', 'Kevin'],
#   'Apellidos_Completos': ['Guaniuna', 'Espinoza'],
#   'Edad:': [30],
#   'Cedula:': 553628322},
#  {'_id': ObjectId('61e8b251f26822fe6b7bcd1b'),
#   'Nombres_Completos': ['Kevin', 'Steven'],
#   'Apellidos_Completos': ['Espinoza', 'Perez'],
#   'Edad:': [73],
#   'Cedula:': 7447990842},
#  {'_id': ObjectId('61e8b251f26822fe6b7bcd1c'),
#   'Nombres_Completos': ['Kevin', 'Kevin'],
#   'Apellidos_Completos': ['Muzo', 'Espinoza'],
#   'Edad:': [24],
#   'Cedula:': 5375626578},
#  {'_id': ObjectId('61e8b251f26822fe6b7bcd1d'),
#   'Nombres_Completos': ['Luis', 'Ricardo'],
#   'Apellidos_Completos': ['Pinanjota', 'Pinanjota'],
#   'Edad:': [22],
#   'Cedula:': 8106706089},
#  {'_id': ObjectId('61e8b251f26822fe6b7bcd1e'),
#   'Nombres_Completos': ['Luis', 'Ricardo'],
#   'Apellidos_Completos': ['Pinanjota', 'Muzo'],
#   'Edad:': [28],
#   'Cedula:': 6599189844},
#  {'_id': ObjectId('61e8b251f26822fe6b7bcd1f'),
#   'Nombres_Completos': ['Jorge', 'Miguel'],
#   'Apellidos_Completos': ['Escobar', 'Escobar'],
#   'Edad:': [56],
#   'Cedula:': 290194470},
#  {'_id': ObjectId('61e8b251f26822fe6b7bcd20'),
#   'Nombres_Completos': ['Miguel', 'Steven'],
#   'Apellidos_Completos': ['Espinoza', 'Escobar'],
#   'Edad:': [33],
#   'Cedula:': 7158376215},
#  {'_id': ObjectId('61e8b252f26822fe6b7bcd21'),
#   'Nombres_Completos': ['Paula', 'Ricardo'],
#   'Apellidos_Completos': ['Perez', 'Pinanjota'],
#   'Edad:': [70],
#   'Cedula:': 7761297609},
#  {'_id': ObjectId('61e8b252f26822fe6b7bcd22'),
#   'Nombres_Completos': ['Steven', 'Jorge'],
#   'Apellidos_Completos': ['Escobar', 'Espinoza'],
#   'Edad:': [31],
#   'Cedula:': 4278351258},
#  {'_id': ObjectId('61e8b252f26822fe6b7bcd23'),
#   'Nombres_Completos': ['Dustin', 'Steven'],
#   'Apellidos_Completos': ['Guaniuna', 'Escobar'],
#   'Edad:': [51],
#   'Cedula:': 8921409687},
#  {'_id': ObjectId('61e8b252f26822fe6b7bcd24'),
#   'Nombres_Completos': ['Miguel', 'Paul'],
#   'Apellidos_Completos': ['Zambrano', 'Chavez'],
#   'Edad:': [58],
#   'Cedula:': 8934184134},
#  {'_id': ObjectId('61e8b252f26822fe6b7bcd25'),
#   'Nombres_Completos': ['Dustin', 'Kevin'],
#   'Apellidos_Completos': ['Zaldumbide', 'Perez'],
#   'Edad:': [32],
#   'Cedula:': 3281012559},
#  {'_id': ObjectId('61e8b252f26822fe6b7bcd26'),
#   'Nombres_Completos': ['Luis', 'Ricardo'],
#   'Apellidos_Completos': ['Perez', 'Espinoza'],
#   'Edad:': [38],
#   'Cedula:': 1076638302},
#  {'_id': ObjectId('61e8b252f26822fe6b7bcd27'),
#   'Nombres_Completos': ['Miguel', 'Steven'],
#   'Apellidos_Completos': ['Chavez', 'Escobar'],
#   'Edad:': [22],
#   'Cedula:': 8765821494},
#  {'_id': ObjectId('61e8b252f26822fe6b7bcd28'),
#   'Nombres_Completos': ['Miguel', 'Ricardo'],
#   'Apellidos_Completos': ['Zaldumbide', 'Perez'],
#   'Edad:': [43],
#   'Cedula:': 1621873863},
#  {'_id': ObjectId('61e8b253f26822fe6b7bcd29'),
#   'Nombres_Completos': ['Ricardo', 'Dustin'],
#   'Apellidos_Completos': ['Zaldumbide', 'Espinoza'],
#   'Edad:': [39],
#   'Cedula:': 5130419886},
#  {'_id': ObjectId('61e8b253f26822fe6b7bcd2a'),
#   'Nombres_Completos': ['Miguel', 'Ricardo'],
#   'Apellidos_Completos': ['Muzo', 'Chavez'],
#   'Edad:': [75],
#   'Cedula:': 8309429478},
#  {'_id': ObjectId('61e8b253f26822fe6b7bcd2b'),
#   'Nombres_Completos': ['Ricardo', 'Paula'],
#   'Apellidos_Completos': ['Espinoza', 'Muzo'],
#   'Edad:': [28],
#   'Cedula:': 7850890980},
#  {'_id': ObjectId('61e8b253f26822fe6b7bcd2c'),
#   'Nombres_Completos': ['Paul', 'Jorge'],
#   'Apellidos_Completos': ['Perez', 'Zaldumbide'],
#   'Edad:': [64],
#   'Cedula:': 3132926208},
#  {'_id': ObjectId('61e8b253f26822fe6b7bcd2d'),
#   'Nombres_Completos': ['Luis', 'Paul'],
#   'Apellidos_Completos': ['Zambrano', 'Guaniuna'],
#   'Edad:': [63],
#   'Cedula:': 753114042}]
